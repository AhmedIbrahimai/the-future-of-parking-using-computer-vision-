# %%
import cv2
import numpy as np
import pickle
import pandas as pd
from ultralytics import YOLO
import cvzone



my_file = open("coco.txt", "r")
data = my_file.read()
class_list = data.split("\n")

model=YOLO('yolov8s.pt')

with open("computervision",'rb') as f:
                data = pickle.load(f)
                polylines , areaName = data['polylines'] , data['areaName']
            
cap=cv2.VideoCapture('easy.mp4')




count=0

while True:
    ret, frame = cap.read()
    if not ret:
        cap.set(cv2.CAP_PROP_POS_FRAMES, 0)
        continue
   
    count += 1
    if count % 3 != 0:
        continue

    frame=cv2.resize(frame,(1200,700))
    frame_copy = frame.copy()
    results=model.predict(frame)
    a=results[0].boxes.data
    px=pd.DataFrame(a).astype("float")
    
    list1=[]
    for index,row in px.iterrows():
 
        x1=int(row[0])
        y1=int(row[1])
        x2=int(row[2])
        y2=int(row[3])
        d=int(row[5])
        
        c=class_list[d]
        cx=int(x1+x2)//2
        cy=int(y1+y2)//2

        if 'car' in c:
            list1.append([cx,cy])
            #cv2.rectangle(frame,(x1,y1),(x2,y2),(255,0,0),2)
            
    counter1 = []        
    for i, polyline in enumerate (polylines):
        cv2.polylines(frame, [polyline], True, (0, 255, 0), 2)
        cvzone.putTextRect(frame,f'{areaName[i]}' , tuple(polyline[0]),1,1)
        
        for l in list1:
            cx1 = l[0]
            cy1 = l[1]
            result = cv2.pointPolygonTest(polyline,(cx1,cy1),False)
            if result >=0:
                cv2.circle(frame,(cx1,cy1),5,(0,255,0),-1)
                cv2.polylines(frame, [polyline], True, (0, 0, 255), 2)
                counter1.append(cx1)
     
    car_count = len(counter1)
    cvzone.putTextRect(frame,f'busy spots is {car_count} ' ,(50,40),2,2)
    free_space = 16 - car_count
    cvzone.putTextRect(frame,f'free spots is {free_space} ' ,(50,90),2,2)
    
    cv2.imshow('FRAME', frame)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break


cap.release()

cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 person, 22 cars, 2333.6ms
# Speed: 13.1ms preprocess, 2333.6ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1819.2ms
# Speed: 102.9ms preprocess, 1819.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 19 cars, 1294.4ms
# Speed: 16.9ms preprocess, 1294.4ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1153.5ms
# Speed: 11.2ms preprocess, 1153.5ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1115.8ms
# Speed: 23.9ms preprocess, 1115.8ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 20 cars, 1316.3ms
# Speed: 11.7ms preprocess, 1316.3ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1607.2ms
# Speed: 14.5ms preprocess, 1607.2ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 21 cars, 1476.3ms
# Speed: 11.1ms preprocess, 1476.3ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 2013.3ms
# Speed: 14.1ms preprocess, 2013.3ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1486.1ms
# Speed: 15.0ms preprocess, 1486.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 2505.8ms
# Speed: 11.2ms preprocess, 2505.8ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 truck, 1710.4ms
# Speed: 10.9ms preprocess, 1710.4ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 truck, 1593.0ms
# Speed: 19.4ms preprocess, 1593.0ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 truck, 1522.1ms
# Speed: 11.4ms preprocess, 1522.1ms inference, 12.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 cars, 1 truck, 3395.9ms
# Speed: 48.1ms preprocess, 3395.9ms inference, 18.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 truck, 9721.2ms
# Speed: 23.7ms preprocess, 9721.2ms inference, 20.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 cars, 1 truck, 6273.4ms
# Speed: 13.0ms preprocess, 6273.4ms inference, 50.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 24 cars, 1 truck, 5976.5ms
# Speed: 26.5ms preprocess, 5976.5ms inference, 70.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 22 cars, 1 bus, 1 truck, 4609.8ms
# Speed: 153.1ms preprocess, 4609.8ms inference, 25.0ms postprocess per image at shape (1, 3, 384, 640)
